# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python

# !pip install mysql-connector-python # install mysql-connector-python package to connect with MySQL 
# !pip install python-dotenv # install python-dotenv package to manage sensitive data in .env files
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import json
import requests
import mysql.connector
from dotenv import load_dotenv


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# load credentials to API and MySQL

load_dotenv(dotenv_path = '/kaggle/input/env-data/env.txt')

API_KEY = os.getenv("API_KEY")
API_HOST = os.getenv("API_HOST")
SEASON = 2024 # year the season started
LEAGUE_ID = 39

# %%
# Connect to API

url = "https://api-football-v1.p.rapidapi.com/v3/standings"
headers = {
	"x-rapidapi-key": API_KEY,
	"x-rapidapi-host": API_HOST
}
querystring = {"league":LEAGUE_ID,
               "season": SEASON}

# %% [markdown]
# **EXTRACT DATA FROM API -  -----------------------------------------------------------**

# %%
# fetch data from API

response = requests.get(url = url, headers = headers, params = querystring)
test = response.json()
test
# Out:
# {'message': 'You are not subscribed to this API.'}
